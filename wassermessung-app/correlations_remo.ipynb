# %% [markdown]
# Speichern Pegeldaten

# %%
import pandas as pd
import json
import matplotlib.pyplot as plt



with open('data/266322010.json', 'r') as file:
    json_data = json.load(file)
parsed_data = json_data[0]["data"]  # Extracting the "data" list
df = pd.DataFrame(parsed_data, columns=["Timestamp", "Value"])

df['Timestamp'] = pd.to_datetime(df['Timestamp'])

# %%
df
# Out:
#                         Timestamp  Value
# 0       2023-12-01 01:00:00+01:00  0.240
# 1       2023-12-01 01:02:00+01:00  0.240
# 2       2023-12-01 01:04:00+01:00  0.240
# 3       2023-12-01 01:06:00+01:00  0.240
# 4       2023-12-01 01:08:00+01:00  0.240
# ...                           ...    ...
# 227180  2024-11-02 00:50:01+01:00  0.059
# 227181  2024-11-02 00:52:01+01:00  0.056
# 227182  2024-11-02 00:54:02+01:00  0.058
# 227183  2024-11-02 00:56:02+01:00  0.058
# 227184  2024-11-02 00:58:02+01:00  0.058
#
# [227185 rows x 2 columns]

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Timestamp'], df['Value'], label='Value', color='blue')


# Format the plot
plt.title('Time Series Plot')
plt.xlabel('Timestamp')
plt.ylabel('Value')
plt.grid(True)
plt.legend()

# Format the plot
plt.title('Time Series Plot')
plt.xlabel('Timestamp')
plt.ylabel('Value')
plt.grid(True)
plt.legend()
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()

# Show the plot
plt.show()
